# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file = "~/logs/training/SqueezeNet-1605261463.6913464.csv"
df = pd.read_csv(file, names=["time", "epoch", "phase", "img_num", "loss", "acc"])
df_train = df[df["phase"] == "train"]
df_val = df[df["phase"] == "val"]

# %%
plt.plot(df_train["img_num"], df_train["acc"])

# %%
plt.plot(df_val["img_num"], df_val["loss"])

# %%
df.tail()
# Out:
#              time  epoch  phase  img_num      loss    acc
# 98   1.605255e+09      2    val    21000  7.158617  2.116
# 99   1.605255e+09      2    val    22000  6.931939  2.120
# 100  1.605255e+09      2    val    23000  7.691905  2.023
# 101  1.605255e+09      3  train    79000  0.244778  1.694
# 102  1.605255e+09      3  train    80000  0.451954  3.828

# %%
# !ls -la ~/checkpoints/
# Out:
# total 156032
# drwxr-xr-x  2 jupyter jupyter     4096 Nov 12 14:33 .
# drwxr-xr-x 16 jupyter jupyter     4096 Nov 12 13:32 ..
# -rw-r--r--  1 jupyter jupyter 79882124 Nov 12 14:00 CNN-1605189142.4673958.data
# -rw-r--r--  1 jupyter jupyter 79882124 Nov 12 15:22 CNN-1605191110.7476783.data
